# %% [markdown]
# ## Importações

# %%
import os
import csv
import requests
try:
    from github import Github
except:
    # !pip install PyGithub
    from github import Github
from pprint import pprint
import pandas as pd
import math

# %% [markdown]
# ## Preparação

# %%
# lista de campos necessários de cada repositório
fieldnames = [
    'id',
    'full_name',
    'name',
    'owner',
    'description',
    'topics',
    'stargazers_count',
    'subscribers_count',
    'fork',
    'forks_count',
    'language',
    'languages',
    # 'has_issues',
    'open_issues_count',
    # 'commits_count',
    # 'last_year_commits_count',
    'contributors_count',
    # 'top_5_contributors',
    'pushed_at',
    'created_at',
    'updated_at',
]

# foi usada a biblioteca PyGithub ao invés de um web-crawler para facilitar a aquisição dos atributos dos repositórios
# no entanto, a api do github possui um limite de 5000 chamadas por hora para contas autenticadas
# dessa forma, vão ser necessárias múltiplas pesquisas espaçadas num intervalo de horas para conseguir dados de milhares de repositórios, considerando que cada repositório resulta em múltiplas chamadas a api
# outro ponto importante é que o github retorna apenas 1000 resultados por pesquisa, então para conseguir >1000 repositórios serão necessárias múltiplas pesquisas

# instanciar wrapper a api do github usando chave de acesso
# duas tokens de acesso, uma para cada pesquisa
key1 = open('key1.txt', 'r').read()
key2 = open('key2.txt', 'r').read()

# g = Github(key1)
g = Github(key2)

# %% [markdown]
# ## Realizar pesquisas na API

# %% [markdown]
# ### Preparação

# %%
def search_api(query, github):
    """
        pesquisa query na api do github e retorna uma lista de dicts com os resultados
    """

    results = github.search_repositories(query=query)
    results_dicts = []

    print(f'{results.totalCount} repositórios encontrados para "{query}".')
    print('iniciando construção da lista de resultados')

    n = 0
    for repo in results:
        topics = repo.get_topics()
        contributors = repo.get_contributors()
        # commits = repo.get_commits()
        languages = repo.get_languages()
        # last_year_commits_count = 0
        # for week in repo.get_stats_commit_activity():
        #     last_year_commits_count += week.total

        results_dicts.append({
            'id': repo.id,
            'full_name': repo.full_name,
            'name': repo.name,
            'owner': repo.owner.login,
            'description': repo.description,
            'topics': ", ".join(topics),
            'stargazers_count': repo.stargazers_count,
            'subscribers_count': repo.subscribers_count,
            'fork': repo.fork,
            'forks_count': repo.forks_count,
            'language': repo.language,
            'languages': ", ".join(languages.keys()),
            # 'has_issues': repo.has_issues,
            'open_issues_count': repo.open_issues_count,
            # 'commits_count': commits.totalCount,
            # 'last_year_commits_count': last_year_commits_count,
            'contributors_count': contributors.totalCount,
            # 'top_5_contributors': [person.login for person in contributors[:5]] if contributors.totalCount > 5 else [],
            'pushed_at': repo.pushed_at,
            'created_at': repo.created_at,
            'updated_at': repo.updated_at,
        })

        n += 1
        print(f'{n}/{results.totalCount}: {repo.full_name} ({math.floor((n/results.totalCount)*100)}%)')

    print('finalizada construção dos resultados')
    return results_dicts

def write_csv_from_results(filename, dict_list, fieldnames, csv):
    """
        escreve um csv usando uma lista de dicts e nomes de colunas
    """

    with open(filename, mode='w', encoding="utf-8") as data_api:
        writer = csv.DictWriter(data_api, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL, fieldnames=fieldnames)
        writer.writeheader()

        for item in dict_list:
            writer.writerow(item)
    print(f'escrito {filename}')

# %% [markdown]
# ### Como serão feitas várias chamadas a api, é importante usar filtros para diminuir o número de chamadas
# ### Também é melhor separar o processo em múltiplas etapas, assim se alcançar o limite podemos fazer outra pesquisa depois e juntar os resultados
# ### De qualquer forma, como o github retorna no máximo 1000 resultados por pesquisa, serão necessárias múltiplas pesquisas

# %%
# %%time

results1 = search_api('blockchain stars:50..120', g)
write_csv_from_results('data-api-1.csv', results1, fieldnames, csv)
# Out:
# : Ashlar/cryptometa (23%)
# 158/668: XTRABYTES/XTRABYTES (23%)
# 159/668: ontio/ontology-ts-sdk (23%)
# 160/668: Ice-Storm/structure-and-interpretation-of-blockchain (23%)
# 161/668: imfly/blockchain-on-nodejs (24%)
# 162/668: simpleapples/py-blockchain-cli (24%)
# 163/668: web3labs/blk-explorer-free (24%)
# 164/668: cynthiablee/blockchain-to-spreadsheet (24%)
# 165/668: Turing-Chain/Honeypots-on-Blockchain (24%)
# 166/668: holgern/beem (24%)
# 167/668: blockchain-certificates/cert-viewer (25%)
# 168/668: hyperledger-archives/iroha-android (25%)
# 169/668: mailchain/mailchain (25%)
# 170/668: airalab/robonomics_contracts (25%)
# 171/668: saber-hq/stable-swap-program (25%)
# 172/668: hitripod/awesome-blockchain (25%)
# 173/668: tronprotocol/tron-contracts (25%)
# 174/668: blockchainedindia/resources (26%)
# 175/668: GetScatter/eos-sharp (26%)
# 176/668: ArkEcosystem/explorer (26%)
# 177/668: CoinAlpha/fund-protocol (26%)
# 178/668: input-output-hk/symphony-2 (26%)
# 179/668: steemit/hivemind (26%)
# 180/668: CortexFoundation/CortexTheseus (26%)
# 181/668: exonum/exonum-java-binding (27%)
# 182/668: phishman3579/Bitcoin (27%)
# 183/668: hyperledger-archives/composer-sample-applications (27%)
# 184/668: IBM-Blockchain-Archive/cp-web (27%)
# 185/668: web3labs/epirus-free (27%)
# 186/668: Blockchain-zju/blockchainer-roadmap (27%)
# 187/668: eosrio/hyperion-history-api (27%)
# 188/668: sarah21cn/BlockChainTechnology (28%)
# 189/668: DecentricCorp/Coval-Unspecified-Ml-Blockchain (28%)
# 190/668: Bunjin/Rouleth (28%)
# 191/668: nomic-io/js-tendermint (28%)
# 192/668: tomochain/tomochain (28%)
# 193/668: hyperledger/iroha-javascript (28%)
# 194/668: davebryson/py-abci (29%)
# 195/668: HydroProtocol/ethereum-watcher (29%)
# 196/668: nguyenkha/kcoin-blockchain (29%)
# 197/668: unwriter/datapay (29%)
# 198/668: nspcc-dev/neo-go (29%)
# 199/668: worldsibu/hurley (29%)
# 200/668: EOSEssentials/EOSDrops (29%)
# 201/668: AtrauraBlockchain/scts (30%)
# 202/668: dappuniversity/social-network (30%)
# 203/668: MichaelBurge/haskoin (30%)
# 204/668: coinorama/coinorama (30%)
# 205/668: danielgerlag/NBlockchain (30%)
# 206/668: MattyIce/steem-keychain (30%)
# 207/668: bpanel-org/bpanel (30%)
# 208/668: shengxinjing/iblockchain (31%)
# 209/668: multi-geth/multi-geth (31%)
# 210/668: oasislabs/oasis-rs (31%)
# 211/668: burst-apps-team/phoenix (31%)
# 212/668: DeFiCh/app (31%)
# 213/668: Arachnid/etherquery (31%)
# 214/668: eosnewyork/eos-transit (32%)
# 215/668: openblocksec/blocksec-incidents (32%)
# 216/668: blockstack/virtualchain (32%)
# 217/668: decred/dcrdocs (32%)
# 218/668: Chaine-de-Blocs/rhizome (32%)
# 219/668: kukai-wallet/kukai (32%)
# 220/668: near/create-near-app (32%)
# 221/668: Mikerah/awesome-privacy-on-blockchains (33%)
# 222/668: CityOfZion/neo-js (33%)
# 223/668: CityOfZion/neo-swift (33%)
# 224/668: MaximilianMeister/kuberneteth (33%)
# 225/668: medibloc/go-medibloc (33%)
# 226/668: Polkadex-Substrate/Polkadex (33%)
# 227/668: paritytech/finality-grandpa (33%)
# 228/668: Azard/web-blockchain-development (34%)
# 229/668: stellar/js-stellar-base (34%)
# 230/668: zmitton/eth-proof (34%)
# 231/668: kotalco/kotal (34%)
# 232/668: yfgeek/CoinOnline (34%)
# 233/668: nebulasio/explorer (34%)
# 234/668: golbin/g-coin (35%)
# 235/668: phantasma-io/PhantasmaChain (35%)
# 236/668: austintgriffith/clevis (35%)
# 237/668: mhxw/hyperledger (35%)
# 238/668: 33cn/plugin (35%)
# 239/668: blkchain/blkchain (35%)
# 240/668: Giveth/feathers-giveth (35%)
# 241/668: beyond-blockchain/bbc1 (36%)
# 242/668: getamis/eth-indexer (36%)
# 243/668: hyperledger-archives/composer-tools (36%)
# 244/668: FISCO-BCOS/whitepaper (36%)
# 245/668: bitshares/bsips (36%)
# 246/668: 0xfe/hacking-stellar (36%)
# 247/668: blocknative/assist (36%)
# 248/668: Izzzio/izzzio (37%)
# 249/668: renproject/multichain (37%)
# 250/668: ArkEcosystem/ark-js (37%)
# 251/668: BlockProject/b-lock (37%)
# 252/668: didil/stone-dapp (37%)
# 253/668: oguzbilgic/zincir (37%)
# 254/668: codemaveric/libra-go (38%)
# 255/668: DAPPBUILDER/dApp-Builder (38%)
# 256/668: EOSLaoMao/elasticsearch_plugin (38%)
# 257/668: devslopes/blockchat (38%)
# 258/668: OpenHFT/Chronicle-Accelerate (38%)
# 259/668: dradtke/go-blockchain (38%)
# 260/668: rchain/bounties (38%)
# 261/668: stellar/laboratory (39%)
# 262/668: hyperledger/fabric-baseimage (39%)
# 263/668: neow3j/neow3j (39%)
# 264/668: hyperledger/iroha-python (39%)
# 265/668: 0xfe/lumen (39%)
# 266/668: near/nearup (39%)
# 267/668: 720kb/BitNFC (39%)
# 268/668: Nethereum/Nethereum-Explorer-Wallet-Template-Blazor (40%)
# 269/668: nexledger/accelerator (40%)
# 270/668: liors/tvdapp (40%)
# 271/668: hiddentao/geth-private (40%)
# 272/668: michain/dotcoin (40%)
# 273/668: stratisproject/Breeze (40%)
# 274/668: stellar/docker-stellar-core (41%)
# 275/668: fractastical/distributed-governance (41%)
# 276/668: target/consensource (41%)
# 277/668: dfuse-io/solana-go (41%)
# 278/668: sugarchain-project/sugarchain (41%)
# 279/668: kesar/eos-awesome-contracts (41%)
# 280/668: EOSpace/eos-sync (41%)
# 281/668: rubykube/workbench (42%)
# 282/668: sealchain-project/sealchain (42%)
# 283/668: kadena-io/chainweb-node (42%)
# 284/668: maticnetwork/pos-portal (42%)
# 285/668: input-output-hk/cardano-ledger-specs (42%)
# 286/668: hyperledger/caliper-benchmarks (42%)
# 287/668: coinmetrics-io/haskell-tools (42%)
# 288/668: bitshares/bitsharesjs (43%)
# 289/668: hhstore/blog (43%)
# 290/668: halilozercan/halocoin (43%)
# 291/668: pixel-point/web3js-tracker-example (43%)
# 292/668: itering/subscan-essentials (43%)
# 293/668: aergoio/aergolite (43%)
# 294/668: integritee-network/substraTEE (44%)
# 295/668: secret-tech/backend-ico-dashboard (44%)
# 296/668: astroband/ruby-stellar-sdk (44%)
# 297/668: chainapsis/keplr-extension (44%)
# 298/668: input-output-hk/iodb (44%)
# 299/668: onflow/flow-ft (44%)
# 300/668: itheima1/hyperledger (44%)
# 301/668: bra1n/cryptolights (45%)
# 302/668: daneah/toyblocks (45%)
# 303/668: EOSIO/eosio-java (45%)
# 304/668: seungwonpark/ghudegy-chain (45%)
# 305/668: trustwallet/watchmarket (45%)
# 306/668: hyperledger-archives/fabric-chaintool (45%)
# 307/668: CityOfZion/neo-privatenet-docker (45%)
# 308/668: second-state/how_to_deploy_uniswap (46%)
# 309/668: Sateetje/awesome-nem-projects (46%)
# 310/668: defiprime/defiprime (46%)
# 311/668: shekhar-shubhendu/supply-chain (46%)
# 312/668: EOSIO/eosio-explorer (46%)
# 313/668: shesek/btproof (46%)
# 314/668: whateverpal/coinmetrics-tools (47%)
# 315/668: nebulasio/nebPay.js (47%)
# 316/668: nemtech/catapult-server (47%)
# 317/668: lludo/BitClout (47%)
# 318/668: CryptoLions/SimpleAssets (47%)
# 319/668: Imaginea/lms (47%)
# 320/668: dddengyunjie/fabric (47%)
# 321/668: evbots/dex-protocols (48%)
# 322/668: nervosnetwork/neuron (48%)
# 323/668: rustyrussell/bitcoin-iterate (48%)
# 324/668: dappuniversity/web3_examples (48%)
# 325/668: eddieoz/haal (48%)
# 326/668: near/near-api-js (48%)
# 327/668: daijiale/ipfs-md-wiki (48%)
# 328/668: Colored-Coins/BankBox (49%)
# 329/668: EOSIO/eosio-project-demux-example (49%)
# 330/668: substrate-developer-hub/cumulus-workshop (49%)
# 331/668: w3f/polkadot-wiki-old (49%)
# 332/668: zeitgeistpm/zeitgeist (49%)
# 333/668: sungjk/s-blockchain (49%)
# 334/668: LayerXcom/cordage (50%)
# 335/668: consenlabs/tokenlon-sdk (50%)
# 336/668: ScopeLift/umbra-protocol (50%)
# 337/668: gochain/gochain (50%)
# 338/668: unwriter/datacash (50%)
# 339/668: freddiecoleman/chia-client (50%)
# 340/668: yutopio/MinChain (50%)
# 341/668: fractalplatform/fractal (51%)
# 342/668: certichain/toychain (51%)
# 343/668: SecurityTokenStandard/EIP-Spec (51%)
# 344/668: stellar-deprecated/bridge-server (51%)
# 345/668: blocklayerhq/chainkit (51%)
# 346/668: singnet/snet-cli (51%)
# 347/668: maximevaillancourt/trace (51%)
# 348/668: TronLink/tronlink-extension (52%)
# 349/668: pbrudny/learning-solidity-2018 (52%)
# 350/668: ripio/rcn-network (52%)
# 351/668: yeasy/cello-archived (52%)
# 352/668: benoit-cty/decentralized_AI (52%)
# 353/668: luckychain/lucky (52%)
# 354/668: gxchain/gxchain-explorer (52%)
# 355/668: WebDollar/Node-WebDollar (53%)
# 356/668: TTCECO/gttc (53%)
# 357/668: StellarCN/scp_zh (53%)
# 358/668: cleanunicorn/karl (53%)
# 359/668: bumoproject/bumo (53%)
# 360/668: Topl/Bifrost (53%)
# 361/668: EOSEssentials/Scatter-Demos (54%)
# 362/668: galacticcouncil/HydraDX-node (54%)
# 363/668: arnaucube/darkID-prototype (54%)
# 364/668: scala-network/scala-v7 (54%)
# 365/668: dmuhs/teatime (54%)
# 366/668: kleros/kleros-interaction (54%)
# 367/668: michaelhly/solana-py (54%)
# 368/668: zilpay/zil-pay (55%)
# 369/668: palletone/go-palletone (55%)
# 370/668: paritytech/substrate-api-sidecar (55%)
# 371/668: wavesplatform/WavesExplorerLite (55%)
# 372/668: spolu/settle (55%)
# 373/668: hyperchain/hyperchain (55%)
# 374/668: olistic/simplechain (55%)
# 375/668: near/near-cli (56%)
# 376/668: HAECHI-LABS/vvisp (56%)
# 377/668: EOSIO/eosio-reference-ios-authenticator-app (56%)
# 378/668: aragon/aragon.js (56%)
# 379/668: decred/dcrdata (56%)
# 380/668: gochain/web3 (56%)
# 381/668: Emurgo/cardano-serialization-lib (57%)
# 382/668: IBM/car-auction-network-fabric-node-sdk (57%)
# 383/668: Sailias/bitcoin_payable (57%)
# 384/668: tatumio/tatum-cli (57%)
# 385/668: openkfw/TruBudget (57%)
# 386/668: near/near-wallet (57%)
# 387/668: JoinColony/colonyJS (57%)
# 388/668: consenlabs/eos-stake-vote-dapp (58%)
# 389/668: sagan-software/eosio-rust (58%)
# 390/668: YaoyaoBae/simchain (58%)
# 391/668: Shitaibin/shitaibin.github.io (58%)
# 392/668: tradle/about (58%)
# 393/668: EOSIO/eosio-swift (58%)
# 394/668: Synthetixio/synthetix-js (58%)
# 395/668: dharmaprotocol/dharma.js (59%)
# 396/668: JMLX42/cocorico (59%)
# 397/668: SaifRehman/tendermint-chat-app (59%)
# 398/668: madfish-solutions/templewallet-extension (59%)
# 399/668: ertugrulyilmaz/awesome-iota (59%)
# 400/668: iron-fish/ironfish (59%)
# 401/668: cosmos/cosmos-academy (60%)
# 402/668: anthdm/hbbft (60%)
# 403/668: copernet/copernicus (60%)
# 404/668: Lamden/contracting (60%)
# 405/668: davidemiceli/chainode (60%)
# 406/668: austintgriffith/token-subscription (60%)
# 407/668: musalbas/trustery (60%)
# 408/668: thelinuxkid/bitcoinquery (61%)
# 409/668: COALAIP/specs (61%)
# 410/668: nanocurrency/nano-docs (61%)
# 411/668: horizontalsystems/bitcoin-kit-android (61%)
# 412/668: Kerala-Blockchain-Academy/AgroChain (61%)
# 413/668: platdrag/UnblockableChains (61%)
# 414/668: algorand/js-algorand-sdk (61%)
# 415/668: blockstack/stacks-wallet-web (62%)
# 416/668: hoprnet/hoprnet (62%)
# 417/668: informalsystems/ibc-rs (62%)
# 418/668: LiuBoyu/hyperledger-fabric-docs-zh_CN (62%)
# 419/668: hero-node/hero-node (62%)
# 420/668: wavesplatform/gowaves (62%)
# 421/668: copperbits/awesome-ton (63%)
# 422/668: ScJa/ercfund (63%)
# 423/668: deanpress/neo-dapp-starter-kit (63%)
# 424/668: CodeChain-io/codechain-explorer (63%)
# 425/668: sthnaqvi/explorer (63%)
# 426/668: adridadou/eth-contract-api (63%)
# 427/668: OpenFuturePlatform/open-chain (63%)
# 428/668: apbendi/use-dai (64%)
# 429/668: devxoul/Blockchain (64%)
# 430/668: DE-labtory/koa (64%)
# 431/668: ConsenSys/bytecode-verifier (64%)
# 432/668: Turing-Chain/Smart-Contract-Modular-Template (64%)
# 433/668: cybercongress/chaingear (64%)
# 434/668: bitcoin-vr/bitcoin-vr (64%)
# 435/668: semuxproject/semux-core (65%)
# 436/668: ConsenSysMesh/live-libs (65%)
# 437/668: xuehuiit/fabric-explorer (65%)
# 438/668: Turing-Chain/TSSKit-Threshold-Signature-Scheme-Toolkit (65%)
# 439/668: ZhongAnTech/Annchain.OG (65%)
# 440/668: Musicoin/desktop (65%)
# 441/668: planetarium/NineChronicles (66%)
# 442/668: EOSEssentials/EOSTracker-API (66%)
# 443/668: elyselam/Etherscan-ML (66%)
# 444/668: centrifuge/go-substrate-rpc-client (66%)
# 445/668: oleiba/blockchain-getting-started (66%)
# 446/668: blockstack/reading-list (66%)
# 447/668: algorand/pyteal (66%)
# 448/668: bigchaindb/privacy-protocols (67%)
# 449/668: EtherTW/jobs (67%)
# 450/668: ConsenSysMesh/cava (67%)
# 451/668: eosspark/geos (67%)
# 452/668: NasaTeam/Nasa.js (67%)
# 453/668: cryptopunksnotdead/programming-cryptopunks (67%)
# 454/668: holochain/clutter (67%)
# 455/668: nsjames/Scatter (68%)
# 456/668: mimblewimble/cuckoo-miner (68%)
# 457/668: voltairelabs/plasma (68%)
# 458/668: ObsidianLabs/AlgorandStudio (68%)
# 459/668: blockchain-council/learn-solidity (68%)
# 460/668: XLNT/gnarly (68%)
# 461/668: dogethereum/dogethereum-contracts (69%)
# 462/668: nucypher/whitepaper (69%)
# 463/668: whiteblock/genesis (69%)
# 464/668: DeBankDeFi/tokendapppub (69%)
# 465/668: Cryptonomic/Tezori (69%)
# 466/668: oceanprotocol/ocean.py (69%)
# 467/668: DOSNetwork/core (69%)
# 468/668: hyperledger/iroha-ios (70%)
# 469/668: wasmx/fizzy (70%)
# 470/668: ultiledger/utoken (70%)
# 471/668: input-output-hk/cardano-ledger-byron (70%)
# 472/668: ElementsProject/elementsproject.org (70%)
# 473/668: Joystream/joystream (70%)
# 474/668: likecoin/likecoin-chain (70%)
# 475/668: snario/zknifty (71%)
# 476/668: domschiener/leaderboard-example (71%)
# 477/668: katopz/awesome-stellar (71%)
# 478/668: toadkicker/awesome-ethereum (71%)
# 479/668: SteadyAction/EtherWalletKit (71%)
# 480/668: circa10a/blockerized-dockchain (71%)
# 481/668: kairen/kubereum (72%)
# 482/668: nebulasio/neb.js (72%)
# 483/668: kesar/ethereum-php (72%)
# 484/668: qlcchain/go-qlc (72%)
# 485/668: apache/incubator-tuweni (72%)
# 486/668: polkascan/py-substrate-interface (72%)
# 487/668: secret-tech/frontend-ico-dashboard (72%)
# 488/668: go-faast/faast-web (73%)
# 489/668: Mindinventory/Mindcoin-CryptoCurrency (73%)
# 490/668: IBM/IPFSfB (73%)
# 491/668: HcashOrg/hcashd (73%)
# 492/668: shanefontaine/ethereum-wallet-comparison (73%)
# 493/668: openblocksec/blocksec-ctfs (73%)
# 494/668: hash3liZer/phishlets (73%)
# 495/668: James-Sangalli/learn-solidity-with-examples (74%)
# 496/668: district0x/memefactory (74%)
# 497/668: web3j/web3j-maven-plugin (74%)
# 498/668: egoist/denote (74%)
# 499/668: skalenetwork/skale-consensus (74%)
# 500/668: MARKETProtocol/MARKETProtocol (74%)
# 501/668: umbracle/minimal (75%)
# 502/668: fairlayer/fair (75%)
# 503/668: counterfactual/paper (75%)
# 504/668: bubicn/bubichain-v3 (75%)
# 505/668: itzmeanjan/ette (75%)
# 506/668: BlockchainOne/WeChat (75%)
# 507/668: SuperblocksHQ/superblocks-lab (75%)
# 508/668: rawtxapp/rawtxapp (76%)
# 509/668: flowchain/flowchain-ledger (76%)
# 510/668: skalenetwork/skale-network (76%)
# 511/668: vechain/thorify (76%)
# 512/668: cypherlink/TDN (76%)
# 513/668: RickWong/bitmex-orderbook (76%)
# 514/668: ladimolnar/BitcoinDatabaseGenerator (76%)
# 515/668: pcko1/bscscan-python (77%)
# 516/668: GalaxyLearning/GFL (77%)
# 517/668: mesg-foundation/engine (77%)
# 518/668: baking-bad/tzkt (77%)
# 519/668: paraswap/paraswap-sdk (77%)
# 520/668: bulwark-crypto/bulwark-explorer (77%)
# 521/668: ubiratansoares/blockked (77%)
# 522/668: bubichain/bubichain (78%)
# 523/668: keyfuse/tokucore (78%)
# 524/668: LayerXcom/anonify (78%)
# 525/668: pokt-network/pocket-core (78%)
# 526/668: chuwt/dive-into-chia (78%)
# 527/668: fbsobreira/gotron-sdk (78%)
# 528/668: enbochen/hyperledger-composer-supply-chain-network (79%)
# 529/668: chatch/stellarexplorer (79%)
# 530/668: ZanjeerPlatform/bargad (79%)
# 531/668: vechain/thor-sync.electron (79%)
# 532/668: DAPSCoin/DAPSCoin (79%)
# 533/668: astroband/astrograph (79%)
# 534/668: unwriter/B (79%)
# 535/668: ChainAgnostic/CAIPs (80%)
# 536/668: jordanlyall/dai-universe (80%)
# 537/668: vedmant/my-little-bitcoin (80%)
# 538/668: enigmampc/enigma-core (80%)
# 539/668: bitwrap/bitwrap-io (80%)
# 540/668: keefertaylor/TezosKit (80%)
# 541/668: vrde/ethnode (80%)
# 542/668: LiskHQ/lisk-mobile (81%)
# 543/668: portis-project/web-sdk (81%)
# 544/668: tintinweb/ethereum-dasm (81%)
# 545/668: skcript/awesome-hyperledger (81%)
# 546/668: district0x/name-bazaar (81%)
# 547/668: dfinity/agent-rs (81%)
# 548/668: nknorg/nkn-client-js (82%)
# 549/668: tatumio/tatum-kms (82%)
# 550/668: AleoHQ/welcome (82%)
# 551/668: flowchain/devify-server (82%)
# 552/668: frogg/Blockchain-Swift-Playground (82%)
# 553/668: IBM/todo-list-fabricV1 (82%)
# 554/668: vkoskiv/VaporCoin (82%)
# 555/668: bonesoul/hypepool (83%)
# 556/668: blackholeorganization/BlackHoleProtocol (83%)
# 557/668: hernandev/curso-blockchain-ethereum (83%)
# 558/668: Confidence-coin/Coco (83%)
# 559/668: webdigi/EOS-Offline-Private-key-check (83%)
# 560/668: izelnakri/eth (83%)
# 561/668: Soneso/stellar-ios-mac-sdk (83%)
# 562/668: piotrmurach/coinpare (84%)
# 563/668: CovenantSQL/CovenantForum (84%)
# 564/668: ErikThiart/cryptocurrency-icons (84%)
# 565/668: Mechanism-Labs/MetaAnalysis-of-Alternative-Consensus-Protocols (84%)
# 566/668: pavlovdog/bitcoin_in_a_nutshell (84%)
# 567/668: airgap-it/airgap-coin-lib (84%)
# 568/668: elucidsoft/dotnet-stellar-sdk (85%)
# 569/668: TokenScript/TokenScript (85%)
# 570/668: scorum/scorum (85%)
# 571/668: iCell/CryptoCurrencyKit (85%)
# 572/668: teller-protocol/teller-protocol-v1 (85%)
# 573/668: witnet/witnet-rust (85%)
# 574/668: perlin-network/smart-contract-rs (85%)
# 575/668: keeshux/bitcoinspv (86%)
# 576/668: AlisProject/serverless-application (86%)
# 577/668: X9Developers/XSN (86%)
# 578/668: input-output-hk/ouroboros-high-assurance (86%)
# 579/668: getamis/istanbul-tools (86%)
# 580/668: nearprotocol/NEARStudio (86%)
# 581/668: tZERO-dev/T0ken (86%)
# 582/668: tendermint/rust-abci (87%)
# 583/668: tjfoc/fabric-ca-gm (87%)
# 584/668: connext/indra (87%)
# 585/668: blockchain-etl/ethereum-etl-airflow (87%)
# 586/668: cosmostation/cosmostation-mobile (87%)
# 587/668: 0xashu/Whale (87%)
# 588/668: OpenST/mosaic-contracts (88%)
# 589/668: nervosnetwork/ckb-explorer-frontend (88%)
# 590/668: nongiach/awesome-cryptocurrency-security (88%)
# 591/668: eth-sri/ilf (88%)
# 592/668: aaroncox/chainbb (88%)
# 593/668: YuniorZen/hub (88%)
# 594/668: w3f/polkadot-deployer (88%)
# 595/668: OriginTrail/ot-node (89%)
# 596/668: farm-army/farm-army-backend (89%)
# 597/668: tonlabs/TON-SDK (89%)
# 598/668: wificoin-project/wwas (89%)
# 599/668: learndapp/awesome-libra (89%)
# 600/668: whoiszxl/zero-mall (89%)
# 601/668: ProChain/SwiftyEOS (89%)
# 602/668: usyd-blockchain/vandal (90%)
# 603/668: openware/barong (90%)
# 604/668: certusone/kb (90%)
# 605/668: TP-Lab/kafka_plugin (90%)
# 606/668: miguelmota/solidity-create2-example (90%)
# 607/668: ciocan/cryptoroulette (90%)
# 608/668: fsn-dev/FDIPs (91%)
# 609/668: AdExNetwork/adex-core (91%)
# 610/668: embarklabs/subspace (91%)
# 611/668: holochain/cryptographic-autonomy-license (91%)
# 612/668: dwyl/phoenix-ecto-append-only-log-example (91%)
# 613/668: neogeno/shango-lightning-wallet (91%)
# 614/668: coti-io/coti-node (91%)
# 615/668: BladeBTC/BladeBTC (92%)
# 616/668: katopz/hello-eth (92%)
# 617/668: transmute-industries/transmute (92%)
# 618/668: ecency/esteem (92%)
# 619/668: nialloc/GameOfLife (92%)
# 620/668: KomodoPlatform/antara-gaming-sdk (92%)
# 621/668: ZenGo-X/multi-party-eddsa (92%)
# 622/668: cosmostation/cosmosjs (93%)
# 623/668: dyne/Zenroom (93%)
# 624/668: PortalNetwork/nifty-game (93%)
# 625/668: skalenetwork/skaled (93%)
# 626/668: cryptopunksnotdead/awesome-cryptopunks-bubble (93%)
# 627/668: ecency/ecency-mobile (93%)
# 628/668: purpleprotocol/purple (94%)
# 629/668: SetProtocol/setprotocol.js (94%)
# 630/668: ecency/esteem-surfer (94%)
# 631/668: blockchain-IoT/Motoro (94%)
# 632/668: WeBankBlockchain/WeDPR-Lab-Core (94%)
# 633/668: dr-orlovsky/library (94%)
# 634/668: planetruby/gems (94%)
# 635/668: cybercongress/cyb-archeology (95%)
# 636/668: manishbisht/Udacity (95%)
# 637/668: goaiquant/GOAi (95%)
# 638/668: dily3825002/awesome-ethereum-cn (95%)
# 639/668: MeadowSuite/Meadow (95%)
# 640/668: ConcealNetwork/conceal-desktop (95%)
# 641/668: carsenk/denarius (95%)
# 642/668: Bitlits/Bitcoin-Slot-Machine (96%)
# 643/668: gauss314/defi (96%)
# 644/668: pRoy24/tokencaps (96%)
# 645/668: ConcealNetwork/conceal-core (96%)
# 646/668: ciri-ethereum/ciri (96%)
# 647/668: accordproject/ergo (96%)
# 648/668: appliedblockchain/k0 (97%)
# 649/668: kamu-data/kamu-cli (97%)
# 650/668: sengineer-io/Software-Engineering-Roadmap (97%)
# 651/668: XDagger/xdagj (97%)
# 652/668: BrightID/BrightID (97%)
# 653/668: ChristopherA/revocable-self-signed-tls-certificates-hack (97%)
# 654/668: Drops-of-Diamond/diamond_drops (97%)
# 655/668: ConsenSysMesh/web3studio-bootleg (98%)
# 656/668: kieranelby/KingOfTheEtherThrone (98%)
# 657/668: Funkmyster/awesome-supply-chain (98%)
# 658/668: layr-team/Layr (98%)
# 659/668: DimensionDev/TesserPG-Android (98%)
# 660/668: vocdoni/vocdoni-node (98%)
# 661/668: PruthviKumarBK/Decentralized_eCom (98%)
# 662/668: liamzebedee/awesome-solidity-patterns (99%)
# 663/668: dappforce/subsocial-web-app (99%)
# 664/668: dennis-tra/image-stego (99%)
# 665/668: scorelab/EtherBeat (99%)
# 666/668: dharma-eng/Tiramisu (99%)
# 667/668: tarcieri/ithos (99%)
# 668/668: coolcode/dfile (100%)
# finalizada construção dos resultados
# escrito data-api-1.csv
# Wall time: 8min 54s

# %%
# %%time

results2 = search_api('blockchain stars:>120', g)
write_csv_from_results('data-api-2.csv', results2, fieldnames, csv)
# Out:
# rnity/protocol (30%)
# 230/754: cosme12/SimpleCoin (30%)
# 231/754: inoutcode/ethereum_book (30%)
# 232/754: U-Network/UNetwork (30%)
# 233/754: aviaviavi/legion (30%)
# 234/754: aitos-io/BoAT-X-Framework (31%)
# 235/754: zack-bitcoin/amoveo (31%)
# 236/754: w3f/polkadot-wiki (31%)
# 237/754: stellar/go (31%)
# 238/754: bitquest/bitquest (31%)
# 239/754: hyperledger/fabric-ca (31%)
# 240/754: tyrchen/unchained (31%)
# 241/754: AplaProject/go-apla (31%)
# 242/754: Azure/coco-framework (32%)
# 243/754: ConsenSys/smart-contract-best-practices (32%)
# 244/754: khipu-io/khipu (32%)
# 245/754: bitshares/bitshares-ui (32%)
# 246/754: okTurtles/blockchainid (32%)
# 247/754: julienr/ipynb_playground (32%)
# 248/754: anders94/public-private-key-demo (32%)
# 249/754: nanocurrency/nano-node (33%)
# 250/754: yep/eth-tweet (33%)
# 251/754: unlock-protocol/unlock (33%)
# 252/754: input-output-hk/cardano-node (33%)
# 253/754: 15Dkatz/cryptochain (33%)
# 254/754: blockchain-jd-com/jdchain (33%)
# 255/754: everitoken/evt (33%)
# 256/754: ethereum/solidity (33%)
# 257/754: CryptoKass/NoobChain-Tutorial-Part-2 (34%)
# 258/754: starcoinorg/starcoin (34%)
# 259/754: slowmist/Knowledge-Base (34%)
# 260/754: XChainLab/documentation (34%)
# 261/754: coinbase/rosetta-specifications (34%)
# 262/754: substrate-developer-hub/recipes (34%)
# 263/754: ledgerwatch/erigon (34%)
# 264/754: Ebookcoin/ebookcoin (35%)
# 265/754: 996BC/996.Blockchain (35%)
# 266/754: hypnopump/pysimplechain (35%)
# 267/754: dsg-titech/simblock (35%)
# 268/754: beurtschipper/crackcoin (35%)
# 269/754: yfgeek/BlockVotes (35%)
# 270/754: ElementsProject/elements (35%)
# 271/754: steemit/steem-python (35%)
# 272/754: blkchain/pg_blkchain (36%)
# 273/754: input-output-hk/plutus (36%)
# 274/754: graphprotocol/graph-node (36%)
# 275/754: EOSEssentials/EOSTracker (36%)
# 276/754: tezos/tezos (36%)
# 277/754: ethereum/mist (36%)
# 278/754: lbryio/lbrycrd (36%)
# 279/754: ooibc88/blockbench (37%)
# 280/754: sunysen/naivechain (37%)
# 281/754: LayerXcom/zero-chain (37%)
# 282/754: exonum/exonum (37%)
# 283/754: DeFiCh/ain (37%)
# 284/754: enzymefinance/oyente (37%)
# 285/754: electric-capital/crypto-ecosystems (37%)
# 286/754: blockstack/stacks.js (37%)
# 287/754: maraoz/proofofexistence (38%)
# 288/754: EOSIO/eosio.contracts (38%)
# 289/754: ConsenSys/ethjsonrpc (38%)
# 290/754: hclivess/Bismuth (38%)
# 291/754: okTurtles/dnschain (38%)
# 292/754: input-output-hk/mantis (38%)
# 293/754: 33cn/chain33 (38%)
# 294/754: cosmos/gaia (38%)
# 295/754: smartcontractkit/chainlink-ruby (39%)
# 296/754: robinmonjo/coincoin (39%)
# 297/754: oasisprotocol/oasis-core (39%)
# 298/754: chjj/termcoin (39%)
# 299/754: ArkEcosystem/core (39%)
# 300/754: MatrixAINetwork/MATRIX_Tutorials (39%)
# 301/754: nervosnetwork/muta (39%)
# 302/754: bitpay/wallet (40%)
# 303/754: nervosnetwork/ckb (40%)
# 304/754: sandoche/Proof-of-Stake-Cryptocurrency-generator (40%)
# 305/754: mitmedialab/medrec (40%)
# 306/754: peercoin/peercoin (40%)
# 307/754: near/nearcore (40%)
# 308/754: ethereumproject/go-ethereum (40%)
# 309/754: ArkEcosystem/desktop-wallet (40%)
# 310/754: ConsenSys/quorum (41%)
# 311/754: status-im/nimbus-eth2 (41%)
# 312/754: MetaMask/metamask-mobile (41%)
# 313/754: ise-ethereum/on-chain-chess (41%)
# 314/754: comaeio/porosity (41%)
# 315/754: thousandetherhomepage/ketherhomepage (41%)
# 316/754: thetatoken/theta-protocol-ledger (41%)
# 317/754: Kava-Labs/kava (42%)
# 318/754: trustwallet/trust-web3-provider (42%)
# 319/754: nebulasio/wiki (42%)
# 320/754: zold-io/zold (42%)
# 321/754: Musicoin/go-musicoin (42%)
# 322/754: yearn/yearn-protocol (42%)
# 323/754: hyperledger/fabric-sdk-go (42%)
# 324/754: MyEtherWallet/MyEtherWallet (42%)
# 325/754: mana-ethereum/ethereumex (43%)
# 326/754: EYBlockchain/nightfall (43%)
# 327/754: Giveth/giveth-dapp (43%)
# 328/754: openhive-network/hive (43%)
# 329/754: mit-dci/CryptoKernel (43%)
# 330/754: studydefi/money-legos (43%)
# 331/754: klaytn/klaytn (43%)
# 332/754: ethereum/fe (44%)
# 333/754: ontio/ontology (44%)
# 334/754: MonsterEOS/monstereos (44%)
# 335/754: thecreazy/chiccocoin (44%)
# 336/754: sablierhq/sablier (44%)
# 337/754: trustwallet/blockatlas (44%)
# 338/754: hyperledger-labs/Scorex (44%)
# 339/754: nebulasio/web-wallet (44%)
# 340/754: ElrondNetwork/elrond-go (45%)
# 341/754: DemocracyEarth/paper (45%)
# 342/754: aksnzhy/bitcoin-bubble-index (45%)
# 343/754: iamtrask/Sonar (45%)
# 344/754: hyperledger/avalon (45%)
# 345/754: onflow/flow-nft (45%)
# 346/754: diesel-rs/diesel (45%)
# 347/754: paritytech/polkadot (46%)
# 348/754: conradoqg/naivecoin (46%)
# 349/754: OpenZeppelin/awesome-openzeppelin (46%)
# 350/754: in3rsha/bitcoin-to-neo4j (46%)
# 351/754: xwiki-contrib/chainpad (46%)
# 352/754: block-core/blockcore (46%)
# 353/754: ddnlink/ddn (46%)
# 354/754: olegabu/fabric-starter (46%)
# 355/754: sebischair/bbse (47%)
# 356/754: cosmos/ibc (47%)
# 357/754: decred/dcrwallet (47%)
# 358/754: MinaProtocol/mina (47%)
# 359/754: aionnetwork/aion (47%)
# 360/754: stellar/dashboard (47%)
# 361/754: bitshares/python-bitshares (47%)
# 362/754: chainHero/heroes-service (48%)
# 363/754: TrueBlocks/trueblocks-core (48%)
# 364/754: Synthetixio/synthetix (48%)
# 365/754: AXErunners/axe (48%)
# 366/754: MixinNetwork/ios-app (48%)
# 367/754: imfly/bitcoin-on-nodejs (48%)
# 368/754: hyperledger/aries-rfcs (48%)
# 369/754: CityOfZion/neon-js (48%)
# 370/754: smartcontractkit/chainlink (49%)
# 371/754: hyperledger-archives/composer-sample-networks (49%)
# 372/754: onflow/kitty-items (49%)
# 373/754: seeleteam/go-seele (49%)
# 374/754: IBM/Decentralized-Energy-Composer (49%)
# 375/754: sero-cash/go-sero (49%)
# 376/754: nuls-io/nuls (49%)
# 377/754: Zilliqa/Zilliqa (50%)
# 378/754: status-im/status-go (50%)
# 379/754: cosmos/iavl (50%)
# 380/754: yuzushioh/EthereumKit (50%)
# 381/754: FIBOSIO/fibos.js (50%)
# 382/754: uport-project/uport-connect (50%)
# 383/754: LiskHQ/lisk-sdk (50%)
# 384/754: makerdao/multicall.js (50%)
# 385/754: rokups/hello-vue-django (51%)
# 386/754: UlordChain/UlordChain (51%)
# 387/754: cranklin/crankycoin (51%)
# 388/754: iov-one/weave (51%)
# 389/754: msilb/coursera-cryptocurrency (51%)
# 390/754: hyperledger/fabric-sdk-java (51%)
# 391/754: ChainSafe/ChainBridge (51%)
# 392/754: eoscanada/eos-go (51%)
# 393/754: web3p/web3.php (52%)
# 394/754: planetarium/libplanet (52%)
# 395/754: AXErunners/electrum-axe (52%)
# 396/754: chain/txvm (52%)
# 397/754: runtimeverification/iele-semantics (52%)
# 398/754: monero-project/monero (52%)
# 399/754: slowmist/eos-smart-contract-security-best-practices (52%)
# 400/754: bekatom/awesome-ethereum (53%)
# 401/754: amaurym/login-with-metamask-demo (53%)
# 402/754: ConsenSys/mythril (53%)
# 403/754: raiden-network/raiden (53%)
# 404/754: hyperledger/fabric-sdk-py (53%)
# 405/754: 0xPolygon/polygon-sdk (53%)
# 406/754: RavenProject/Ravencoin (53%)
# 407/754: telehash/blockname (53%)
# 408/754: meshplus/bitxhub (54%)
# 409/754: lbryio/spee.ch (54%)
# 410/754: lbryio/chainquery (54%)
# 411/754: EOSIO/demux-js (54%)
# 412/754: hyperledger/cactus (54%)
# 413/754: ethereum/remix (54%)
# 414/754: dfinity/ic (54%)
# 415/754: lightningnetwork/lightning-rfc (55%)
# 416/754: GetScatter/ScatterWebExtension (55%)
# 417/754: ChainSafe/forest (55%)
# 418/754: iov-one/iov-core (55%)
# 419/754: hyperledger/fabric-sdk-node (55%)
# 420/754: BlueWallet/BlueWallet (55%)
# 421/754: proofofexistence/proofofexistence (55%)
# 422/754: kadena-io/pact (55%)
# 423/754: tendermint/go-amino (56%)
# 424/754: manojpramesh/solidity-cheatsheet (56%)
# 425/754: inoutcode/bitcoin_book_2nd (56%)
# 426/754: eoscanada/eos-bios (56%)
# 427/754: Awesome-Layer-2/awesome-layer-2 (56%)
# 428/754: Conflux-Chain/conflux-rust (56%)
# 429/754: gobitfly/erc20-explorer (56%)
# 430/754: sebs/etherscan-api (57%)
# 431/754: nebulasio/WebExtensionWallet (57%)
# 432/754: IBM/evote (57%)
# 433/754: substrate-developer-hub/awesome-substrate (57%)
# 434/754: StellarCN/py-stellar-base (57%)
# 435/754: Nikhil22/angular-truffle-starter-dapp (57%)
# 436/754: cryptape/ruby-ethereum (57%)
# 437/754: hyperledger-archives/iroha (57%)
# 438/754: ivoras/daisy (58%)
# 439/754: stratisproject/StratisBitcoinFullNode (58%)
# 440/754: onflow/flow (58%)
# 441/754: stellar/java-stellar-sdk (58%)
# 442/754: web3j/sample-project-gradle (58%)
# 443/754: dapperlabs/nba-smart-contracts (58%)
# 444/754: ArkEcosystem/ark-node (58%)
# 445/754: theQRL/QRL (59%)
# 446/754: district0x/ethlance (59%)
# 447/754: lightningnetwork/lnd (59%)
# 448/754: btccom/btcpool-ABANDONED (59%)
# 449/754: bitcoin-wallet/bitcoin-wallet (59%)
# 450/754: tendermint/tendermint (59%)
# 451/754: WeBankFinTech/WeEvent (59%)
# 452/754: ConsenSys/defi-score (59%)
# 453/754: EOSIO/eosio-project-boilerplate-simple (60%)
# 454/754: ObsidianLabs/ConfluxStudio (60%)
# 455/754: pventuzelo/octopus (60%)
# 456/754: MixinNetwork/ocean.one (60%)
# 457/754: SqueezerIO/squeezer (60%)
# 458/754: blockchain/unused-My-Wallet-iPhone (60%)
# 459/754: holochain/holochain-rust (60%)
# 460/754: decred/dcrd (61%)
# 461/754: priestc/moneywagon (61%)
# 462/754: stellar/slingshot (61%)
# 463/754: luniehq/lunie (61%)
# 464/754: argentlabs/web3.swift (61%)
# 465/754: reach-sh/reach-lang (61%)
# 466/754: eoscanada/eosc (61%)
# 467/754: LedgerHQ/ledger-nano-s (61%)
# 468/754: Graphite-Docs/graphite (62%)
# 469/754: mikispag/bitiodine (62%)
# 470/754: ACINQ/eclair (62%)
# 471/754: aragon/client (62%)
# 472/754: philipperemy/my-first-bitcoin-miner (62%)
# 473/754: slowmist/eos-bp-nodes-security-checklist (62%)
# 474/754: ConsenSys/anonymous-zether (62%)
# 475/754: web3j/web3j (62%)
# 476/754: input-output-hk/ouroboros-network (63%)
# 477/754: uport-project/uport-credentials (63%)
# 478/754: zhuowei/nft_ptr (63%)
# 479/754: FactomProject/factomd (63%)
# 480/754: stellar/js-stellar-sdk (63%)
# 481/754: wupeaking/tendermint_code_analysis (63%)
# 482/754: onflow/flow-js-sdk (63%)
# 483/754: paritytech/parity-bitcoin (64%)
# 484/754: loomnetwork/cryptozombies-lesson-code (64%)
# 485/754: enzymefinance/protocol (64%)
# 486/754: hyperledger/quilt (64%)
# 487/754: WasmEdge/WasmEdge (64%)
# 488/754: hashgraph/awesome-hashgraph (64%)
# 489/754: ConsenSys/cakeshop (64%)
# 490/754: project-serum/anchor (64%)
# 491/754: jklepatch/eattheblocks (65%)
# 492/754: DevanaLabs/lemon.email-dApp (65%)
# 493/754: jollen/nodejs-fullstack-book (65%)
# 494/754: comit-network/comit-rs (65%)
# 495/754: nos/client (65%)
# 496/754: blockstack/stacks-wallet (65%)
# 497/754: Netherdrake/awesome-eos (65%)
# 498/754: popshootjapan/WeiWallet-iOS (66%)
# 499/754: hyfen-nl/PIVT (66%)
# 500/754: holochain/holochain-proto (66%)
# 501/754: iExecBlockchainComputing/iexec-sdk (66%)
# 502/754: Chia-Network/chiapos (66%)
# 503/754: kulapio/libra-wallet-poc (66%)
# 504/754: ecadlabs/taquito (66%)
# 505/754: hyperledger/aries (66%)
# 506/754: dtube/dtube (67%)
# 507/754: irisnet/irishub (67%)
# 508/754: ObsidianLabs/CKB-Studio (67%)
# 509/754: kulupu/kulupu (67%)
# 510/754: ethereum/evmone (67%)
# 511/754: mempoolco/spruned (67%)
# 512/754: poetapp/node (67%)
# 513/754: maticnetwork/dagger.js (68%)
# 514/754: okex/exchain (68%)
# 515/754: onflow/flow-go (68%)
# 516/754: mysteriumnetwork/node (68%)
# 517/754: certikfoundation/shentu (68%)
# 518/754: truechain/truechain-consensus-core (68%)
# 519/754: onflow/flow-go-sdk (68%)
# 520/754: wumansgy/GoAndBlockChainStudy (68%)
# 521/754: a-mitani/mastering-ethereum (69%)
# 522/754: pixelspark/catena (69%)
# 523/754: status-im/open-bounty (69%)
# 524/754: aa-miner/aaminer (69%)
# 525/754: dbjsdev/BrewChain (69%)
# 526/754: diadata-org/diadata (69%)
# 527/754: tarassh/fairy-wallet (69%)
# 528/754: embarklabs/embark (70%)
# 529/754: protofire/eth-cli (70%)
# 530/754: CodeChain-io/codechain (70%)
# 531/754: PegaSysEng/pantheon (70%)
# 532/754: onuar/dokuztas (70%)
# 533/754: ElementsProject/simplicity (70%)
# 534/754: FileNation/FileNation (70%)
# 535/754: status-im/status-network-token (70%)
# 536/754: microsoft/eEVM (71%)
# 537/754: bandprotocol/bandchain (71%)
# 538/754: nknorg/nkn (71%)
# 539/754: meritlabs/merit (71%)
# 540/754: lbryio/lbry-desktop (71%)
# 541/754: TokenMarketNet/smart-contracts (71%)
# 542/754: NebulousLabs/Sia-UI (71%)
# 543/754: 409H/EtherAddressLookup (72%)
# 544/754: ElixiumNetwork/elixium_core (72%)
# 545/754: ClearGDPR/ClearGDPR (72%)
# 546/754: insight-chain/inb-go (72%)
# 547/754: trustwallet/trust-wallet-ios (72%)
# 548/754: yearn/yearn-vaults (72%)
# 549/754: ethersphere/swarm (72%)
# 550/754: slowmist/papers (72%)
# 551/754: LiskHQ/lisk-desktop (73%)
# 552/754: MixinNetwork/mixin (73%)
# 553/754: HydroProtocol/hydro-scaffold-dex (73%)
# 554/754: dtube/production (73%)
# 555/754: cosmos/ethermint (73%)
# 556/754: Bytom/bytom (73%)
# 557/754: forbole/big-dipper (73%)
# 558/754: ThatOtherZach/Web3-by-Example (74%)
# 559/754: ripple/ripple-lib (74%)
# 560/754: vacuumlabs/adalite (74%)
# 561/754: maticnetwork/contracts (74%)
# 562/754: horizontalsystems/bitcoin-kit-ios (74%)
# 563/754: JoinColony/colonyNetwork (74%)
# 564/754: simondlr/computingcommons (74%)
# 565/754: cloudhead/nakamoto (74%)
# 566/754: renepickhardt/The-Lightning-Network-Book (75%)
# 567/754: thallium205/BitcoinVisualizer (75%)
# 568/754: hyperledger/burrow (75%)
# 569/754: QuarkChain/pyquarkchain (75%)
# 570/754: artonomous/artonomous-mvp (75%)
# 571/754: superoneio/awesome-eos (75%)
# 572/754: lnbook/lnbook (75%)
# 573/754: intellij-solidity/intellij-solidity (75%)
# 574/754: MixinNetwork/android-app (76%)
# 575/754: mvs-org/metaverse (76%)
# 576/754: bitconch/bitconch-core (76%)
# 577/754: NasaTeam/Awesome-Nebulas (76%)
# 578/754: web3labs/erc20-rest-service (76%)
# 579/754: EthVM/EthVM (76%)
# 580/754: xianfeng92/Love-Ethereum (76%)
# 581/754: solana-labs/solana-web3.js (77%)
# 582/754: ZuInnoTe/hadoopcryptoledger (77%)
# 583/754: blocknetdx/blocknet (77%)
# 584/754: ovrclk/akash (77%)
# 585/754: tintinweb/smart-contract-sanctuary (77%)
# 586/754: tjfoc/hyperledger-fabric-gm (77%)
# 587/754: AleoHQ/snarkOS (77%)
# 588/754: DemocracyEarth/dapp (77%)
# 589/754: dfuse-io/dfuse-eosio (78%)
# 590/754: tintinweb/ecdsa-private-key-recovery (78%)
# 591/754: bitcoin-s/bitcoin-s (78%)
# 592/754: ConsenSys/tessera (78%)
# 593/754: EOSIO/eosio-card-game-repo (78%)
# 594/754: DwyaneQ/ETHWallet (78%)
# 595/754: Zilliqa/scilla (78%)
# 596/754: harmony-one/harmony (79%)
# 597/754: skycoin/skycoin (79%)
# 598/754: xiaoyao1991/presto-ethereum (79%)
# 599/754: ong/awesome-decentralized-finance (79%)
# 600/754: xipfs/IPFS-Internals (79%)
# 601/754: hyperledger/fabric-gateway-java (79%)
# 602/754: dabit3/full-stack-ethereum (79%)
# 603/754: ethereumbook/ethereumbook (79%)
# 604/754: holochain/holochain (80%)
# 605/754: ProofSuite/amp-matching-engine (80%)
# 606/754: trufflesuite/truffle (80%)
# 607/754: chrisdannen/Introducing-Ethereum-and-Solidity (80%)
# 608/754: PlasmNetwork/Plasm (80%)
# 609/754: cloudframeworks-blockchain/user-guide-fabric-smart-contract (80%)
# 610/754: jpantunes/awesome-cryptoeconomics (80%)
# 611/754: cosmos/ethermint-archive (81%)
# 612/754: deroproject/derosuite (81%)
# 613/754: GetScatter/ScatterDesktop (81%)
# 614/754: web3j/web3j-spring-boot-starter (81%)
# 615/754: Axentro/Axentro (81%)
# 616/754: BeamMW/beam (81%)
# 617/754: consenlabs/token-core (81%)
# 618/754: ethereum-ts/TypeChain (81%)
# 619/754: courtneyes/ConsenSys-Academy-Notes (82%)
# 620/754: bitcoinj/bitcoinj (82%)
# 621/754: arcbit/arcbit-ios (82%)
# 622/754: armors/armors-solidity (82%)
# 623/754: cryptokylin/CryptoKylin-Testnet (82%)
# 624/754: Neufund/smart-contract-watch (82%)
# 625/754: DE-labtory/it-chain (82%)
# 626/754: kleros/kleros (83%)
# 627/754: loomnetwork/loom-js (83%)
# 628/754: ethereum/remix-project (83%)
# 629/754: celo-org/celo-monorepo (83%)
# 630/754: AschPlatform/asch (83%)
# 631/754: nervosnetwork/ckb-vm (83%)
# 632/754: koltenb/awesome-stellar (83%)
# 633/754: deeponion/deeponion-legacy (83%)
# 634/754: everitoken/evt4j (84%)
# 635/754: AlphaWallet/alpha-wallet-android (84%)
# 636/754: hyperledger/iroha (84%)
# 637/754: onflow/flow-cli (84%)
# 638/754: ZenGo-X/multi-party-ecdsa (84%)
# 639/754: XDagger/xdag (84%)
# 640/754: MatrixAINetwork/go-matrix (84%)
# 641/754: CREDITSCOM/node (85%)
# 642/754: Muterra/doc-golix (85%)
# 643/754: AgregoreWeb/agregore-browser (85%)
# 644/754: interledger/rfcs (85%)
# 645/754: paritytech/parity-zcash (85%)
# 646/754: copperbits/TON (85%)
# 647/754: OCamlPro/liquidity (85%)
# 648/754: trustwallet/trust-ray (85%)
# 649/754: datproject/sdk (86%)
# 650/754: vitelabs/go-vite (86%)
# 651/754: jasonwalsh/awesome-dapps (86%)
# 652/754: eBTC-Official/eBTC (86%)
# 653/754: nestdotland/nest.land (86%)
# 654/754: status-im/status-react (86%)
# 655/754: eventeum/eventeum (86%)
# 656/754: cryptocopycats/awesome-cryptokitties-bubble (87%)
# 657/754: ConsenSys/ethql (87%)
# 658/754: AztecProtocol/AZTEC (87%)
# 659/754: adrianmcli/eth95 (87%)
# 660/754: adamyala/Your_First_Decentralized_Application_Python (87%)
# 661/754: ethereum/remix-ide (87%)
# 662/754: lbryio/lbry-sdk (87%)
# 663/754: ZenGo-X/multi-party-schnorr (87%)
# 664/754: chawyehsu/dorado (88%)
# 665/754: clearmatics/ion (88%)
# 666/754: second-state/buidl (88%)
# 667/754: MedPoints/site (88%)
# 668/754: Scanate/EthList (88%)
# 669/754: blockstack/blockstack.org (88%)
# 670/754: BlockchainCommons/Learning-Bitcoin-from-the-Command-Line (88%)
# 671/754: Nethereum/Nethereum (88%)
# 672/754: vergecurrency/verge (89%)
# 673/754: trailofbits/manticore (89%)
# 674/754: ACINQ/eclair-mobile (89%)
# 675/754: cellcycle/go-web3 (89%)
# 676/754: blockstarter/ico-contracts (89%)
# 677/754: 1200wd/bitcoinlib (89%)
# 678/754: ethereum/py-solc (89%)
# 679/754: OffcierCia/ultimate-defi-research-base (90%)
# 680/754: amark/gun (90%)
# 681/754: firoorg/firo (90%)
# 682/754: WeBankBlockchain/WeCross (90%)
# 683/754: nomiclabs/hardhat (90%)
# 684/754: perlin-network/wavelet (90%)
# 685/754: enkidevs/curriculum (90%)
# 686/754: aeternity/elixir-node (90%)
# 687/754: aeternity/aeternity (91%)
# 688/754: jonluo94/baasmanager (91%)
# 689/754: blockstack/blockstack-browser (91%)
# 690/754: pibigstar/go-demo (91%)
# 691/754: BlockchainDevs/CryptocurrencyAwesome (91%)
# 692/754: yogh-io/bitcoin-transaction-explorer (91%)
# 693/754: rotki/rotki (91%)
# 694/754: rule110-io/surge (92%)
# 695/754: second-state/SOLL (92%)
# 696/754: FleekHQ/space-daemon (92%)
# 697/754: DimensionDev/Maskbook (92%)
# 698/754: pandonetwork/pando (92%)
# 699/754: algobasket/PeatioCryptoExchange (92%)
# 700/754: spacemeshos/go-spacemesh (92%)
# 701/754: AlphaWallet/alpha-wallet-ios (92%)
# 702/754: COVID-19-electronic-health-system/Corona-tracker (93%)
# 703/754: ethereum-oasis/baseline (93%)
# 704/754: status-im/nimbus-eth1 (93%)
# 705/754: w3f/polkadot-validator-setup (93%)
# 706/754: miguelmota/cointop (93%)
# 707/754: miguelmota/go-ethereum-hdwallet (93%)
# 708/754: pluralsight/guides (93%)
# 709/754: jjxtra/ExchangeSharp (94%)
# 710/754: miguelmota/ethereum-development-with-go-book (94%)
# 711/754: rampatra/Algorithms-and-Data-Structures-in-Java (94%)
# 712/754: MedPoints/api (94%)
# 713/754: Lonero-Team/Decentralized-Internet (94%)
# 714/754: chatch/hashed-timelock-contract-ethereum (94%)
# 715/754: interledger-rs/interledger-rs (94%)
# 716/754: iotaledger/bee (94%)
# 717/754: stellar/kelp (95%)
# 718/754: DeltaBalances/DeltaBalances.github.io (95%)
# 719/754: hanzoai/hanzo.js (95%)
# 720/754: WeBankFinTech/WeIdentity (95%)
# 721/754: ico-check/ico-check (95%)
# 722/754: DOkwufulueze/eth-vue (95%)
# 723/754: goldennetwork/golden-wallet-react-native (95%)
# 724/754: MitchPierias/advanced-eos-examples (96%)
# 725/754: Bitlits/Bitcoin-Casino (96%)
# 726/754: pubkey/eth-crypto (96%)
# 727/754: CoinAlpha/hummingbot_chinese (96%)
# 728/754: horizontalsystems/unstoppable-wallet-android (96%)
# 729/754: fluidtrends/carmel (96%)
# 730/754: leopoldjoy/react-ethereum-dapp-example (96%)
# 731/754: CodeChefVIT/resources (96%)
# 732/754: YsnKsy/react-native-geth (97%)
# 733/754: horizontalsystems/unstoppable-wallet-ios (97%)
# 734/754: maxim5/time-series-machine-learning (97%)
# 735/754: accordproject/cicero (97%)
# 736/754: cybercongress/congress (97%)
# 737/754: KomodoPlatform/atomicDEX-Desktop (97%)
# 738/754: miguelmota/merkletreejs (97%)
# 739/754: enigmampc/SecretNetwork (98%)
# 740/754: guydavis/machinaris (98%)
# 741/754: particl/particl-desktop (98%)
# 742/754: 0xcert/framework (98%)
# 743/754: cybercongress/go-cyber (98%)
# 744/754: dgynfi/OpenSource (98%)
# 745/754: harveybc/gym-fx (98%)
# 746/754: Adamant-im/adamant-im (98%)
# 747/754: ticket721/ethvtx (99%)
# 748/754: zbarge/stocklook (99%)
# 749/754: redwood/redwood (99%)
# 750/754: atlaschiew/bitcoin-cryptocurrency-tutorial (99%)
# 751/754: polyrabbit/my-token (99%)
# 752/754: Texnomic/SecureDNS (99%)
# 753/754: fergarrui/ethereum-graph-debugger (99%)
# 754/754: second-state/smart-contract-search-engine (100%)
# finalizada construção dos resultados
# escrito data-api-2.csv
# Wall time: 9min 42s

# %% [markdown]
# ## Combinando resultados

# %%
files = [
    pd.read_csv('data-api-1.csv'),
    pd.read_csv('data-api-2.csv'),
]

dataset = pd.concat(files, ignore_index=True).sort_values('id').reset_index(drop=True)
dataset.to_csv('dataset.csv', index=False)

# %%
dataset
# Out:
#              id                               full_name  \
# 0       2304420             bitcoin-dot-org/Bitcoin.org
# 1       2724167                          ripple/rippled
# 2       2877991                    mhanne/block_browser
# 3       3886965           bitcoin-wallet/bitcoin-wallet
# 4       3900173      blockchain/unused-My-Wallet-iPhone
# ...         ...                                     ...
# 1417  363445257                     guydavis/machinaris
# 1418  365701873                              dfinity/ic
# 1419  367841354     ChainGreenOrg/chaingreen-blockchain
# 1420  376155268  OffcierCia/ultimate-defi-research-base
# 1421  377341156            Flax-Network/flax-blockchain
#
#                              name            owner  \
# 0                     Bitcoin.org  bitcoin-dot-org
# 1                         rippled           ripple
# 2                   block_browser           mhanne
# 3                  bitcoin-wallet   bitcoin-wallet
# 4         unused-My-Wallet-iPhone       blockchain
# ...                           ...              ...
# 1417                   machinaris         guydavis
# 1418                           ic          dfinity
# 1419        chaingreen-blockchain    ChainGreenOrg
# 1420  ultimate-defi-research-base       OffcierCia
# 1421              flax-blockchain     Flax-Network
#
#                                             description  \
# 0                                   Bitcoin.org Website
# 1     Decentralized cryptocurrency blockchain daemon...
# 2                            Bitcoin Blockchain Browser
# 3     Bitcoin Wallet app for your Android device. St...
# 4     For latest source, please see: https://github....
# ...                                                 ...
# 1417  An easy-to-use WebUI for Chia plotting and far...
# 1418  Internet Computer blockchain source: the clien...
# 1419                                                NaN
# 1420  Here we collect and discuss the best DeFI & Bl...
# 1421                                                NaN
#
#                                                  topics  stargazers_count  \
# 0              bitcoin, blockchain, cryptocurrency, p2p              1150
# 1     xrpl, xrp-ledger, xrp, cplusplus, c-plus-plus,...              3877
# 2                                                   NaN                51
# 3     bitcoin, bitcoinj, bitcoin-wallet, android, ja...              2475
# 4                                                   NaN               128
# ...                                                 ...               ...
# 1417  chia, plotting, webui, plotman, chia-network, ...               131
# 1418                                                NaN               653
# 1419                                                NaN                50
# 1420                                                NaN               164
# 1421                                                NaN                66
#
#       subscribers_count   fork  forks_count  language  \
# 0                   228  False         1931      HTML
# 1                   506  False         1229       C++
# 2                     7  False           22      Ruby
# 3                   475  False         1660      Java
# 4                    30  False           66  Assembly
# ...                 ...    ...          ...       ...
# 1417                 16  False           17    Python
# 1418                 41  False           49      Rust
# 1419                  7  False           21    Python
# 1420                 11  False           19       NaN
# 1421                 10  False           13    Python
#
#                                               languages  open_issues_count  \
# 0     HTML, SCSS, JavaScript, Less, Ruby, Shell, Mak...                 70
# 1     C++, C, CMake, Shell, JavaScript, Java, Sage, ...                294
# 2             Ruby, HTML, CoffeeScript, CSS, JavaScript                 11
# 3                                                  Java                 86
# 4     Assembly, C, Objective-C, C++, HTML, Objective...                  6
# ...                                                 ...                ...
# 1417         Python, HTML, Shell, PowerShell, CSS, Mako                 19
# 1418  Rust, WebAssembly, Shell, Dockerfile, HTML, Mo...                  0
# 1419              Python, Shell, PowerShell, Dockerfile                 24
# 1420                                                NaN                  0
# 1421                          Python, Shell, PowerShell                  5
#
#       contributors_count            pushed_at           created_at  \
# 0                    334  2021-06-23 11:51:52  2011-08-31 21:58:01
# 1                     89  2021-06-23 09:11:32  2011-11-07 04:40:15
# 2                      2  2016-07-21 15:07:16  2011-11-29 20:44:00
# 3                     27  2021-05-30 15:13:32  2012-03-31 17:06:47
# 4                      9  2015-09-01 21:20:50  2012-04-02 12:01:57
# ...                  ...                  ...                  ...
# 1417                   3  2021-06-27 19:58:47  2021-05-01 15:36:50
# 1418                   1  2021-06-24 09:00:37  2021-05-09 08:16:37
# 1419                  71  2021-06-24 12:15:26  2021-05-16 09:53:27
# 1420                   7  2021-06-25 00:44:38  2021-06-11 22:27:41
# 1421                  68  2021-06-21 08:58:06  2021-06-16 01:52:16
#
#                updated_at
# 0     2021-06-24 04:36:53
# 1     2021-06-25 17:08:35
# 2     2019-09-26 01:05:39
# 3     2021-06-26 07:22:42
# 4     2021-02-15 00:40:30
# ...                   ...
# 1417  2021-06-27 19:10:49
# 1418  2021-06-27 18:52:09
# 1419  2021-06-27 18:09:29
# 1420  2021-06-27 18:50:43
# 1421  2021-06-27 18:11:25
#
# [1422 rows x 17 columns]
